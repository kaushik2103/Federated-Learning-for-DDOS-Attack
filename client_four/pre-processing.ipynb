# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('D:/AIT-ME-DS/Sem_3/In-House-Research-I-Project/Federated-Learning-for-DDOS-Attack/client_four/raw-dataset/client-4-DDOS-SDN-Dataset/dataset_sdn.csv')

# %%
df.isnull().sum()
# Out:
# dt               0
# switch           0
# src              0
# dst              0
# pktcount         0
# bytecount        0
# dur              0
# dur_nsec         0
# tot_dur          0
# flows            0
# packetins        0
# pktperflow       0
# byteperflow      0
# pktrate          0
# Pairflow         0
# Protocol         0
# port_no          0
# tx_bytes         0
# rx_bytes         0
# tx_kbps          0
# rx_kbps        506
# tot_kbps       506
# label            0
# dtype: int64

# %%
df.drop(columns=['rx_kbps', 'tot_kbps'], inplace=True)

# %%
df
# Out:
#            dt  switch        src       dst  pktcount  bytecount  dur  \
# 0       11425       1   10.0.0.1  10.0.0.8     45304   48294064  100
# 1       11605       1   10.0.0.1  10.0.0.8    126395  134737070  280
# 2       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# 3       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# 4       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# ...       ...     ...        ...       ...       ...        ...  ...
# 104340   5262       3   10.0.0.5  10.0.0.7        79       7742   81
# 104341   5262       3   10.0.0.5  10.0.0.7        79       7742   81
# 104342   5262       3  10.0.0.11  10.0.0.5        31       3038   31
# 104343   5262       3  10.0.0.11  10.0.0.5        31       3038   31
# 104344   5262       3  10.0.0.11  10.0.0.5        31       3038   31
#
#          dur_nsec       tot_dur  flows  ...  pktperflow  byteperflow  pktrate  \
# ...

# %%
label_encoder = LabelEncoder()
df['Protocol'] = label_encoder.fit_transform(df['Protocol'])

# %%
df
# Out:
#            dt  switch        src       dst  pktcount  bytecount  dur  \
# 0       11425       1   10.0.0.1  10.0.0.8     45304   48294064  100
# 1       11605       1   10.0.0.1  10.0.0.8    126395  134737070  280
# 2       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# 3       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# 4       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# ...       ...     ...        ...       ...       ...        ...  ...
# 104340   5262       3   10.0.0.5  10.0.0.7        79       7742   81
# 104341   5262       3   10.0.0.5  10.0.0.7        79       7742   81
# 104342   5262       3  10.0.0.11  10.0.0.5        31       3038   31
# 104343   5262       3  10.0.0.11  10.0.0.5        31       3038   31
# 104344   5262       3  10.0.0.11  10.0.0.5        31       3038   31
#
#          dur_nsec       tot_dur  flows  ...  pktperflow  byteperflow  pktrate  \
# ...

# %%
df.to_csv('D:/AIT-ME-DS/Sem_3/In-House-Research-I-Project/Federated-Learning-for-DDOS-Attack/client_four/processed-dataset/client-4-processed_dataset.csv')

# %%
df = pd.read_csv('D:/AIT-ME-DS/Sem_3/In-House-Research-I-Project/Federated-Learning-for-DDOS-Attack/client_four/processed-dataset/client-4-processed_dataset.csv')

# %%
df
# Out:
#         Unnamed: 0     dt  switch        src       dst  pktcount  bytecount  \
# 0                0  11425       1   10.0.0.1  10.0.0.8     45304   48294064
# 1                1  11605       1   10.0.0.1  10.0.0.8    126395  134737070
# 2                2  11425       1   10.0.0.2  10.0.0.8     90333   96294978
# 3                3  11425       1   10.0.0.2  10.0.0.8     90333   96294978
# 4                4  11425       1   10.0.0.2  10.0.0.8     90333   96294978
# ...            ...    ...     ...        ...       ...       ...        ...
# 104340      104340   5262       3   10.0.0.5  10.0.0.7        79       7742
# 104341      104341   5262       3   10.0.0.5  10.0.0.7        79       7742
# 104342      104342   5262       3  10.0.0.11  10.0.0.5        31       3038
# 104343      104343   5262       3  10.0.0.11  10.0.0.5        31       3038
# 104344      104344   5262       3  10.0.0.11  10.0.0.5        31       3038
#
# ...
